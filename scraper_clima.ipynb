# %%
# !pip install demjson

# https://www.timeanddate.com/weather/australia/sydney/historic?month=7&year=2012
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.5/131.5 KB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for demjson: filename=demjson-2.2.4-py3-none-any.whl size=73565 sha256=0df0a021ee6f9df844431e865b233ef00dcaf51d56cac84cc896882955ea276f
#   Stored in directory: /root/.cache/pip/wheels/9c/c3/a5/ad09d152d6b4b24c3f3b6fe2793092ac03e2521e08240d28cf
# Successfully built demjson
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
import demjson
from unicodedata import normalize
from datetime import datetime, timedelta

# %%
def get_data(date, month, year):
  cookies = {
      '_pbjs_userid_consent_data': '3524755945110770',
      '_sharedID': 'c673f09b-e619-43c6-971b-c0d67e16f49c',
      '__gads': 'ID=29480aa4712e38d7:T=1675200257:S=ALNI_MZv1zk4XHCqgmGiU-c0XTo4bbdBww',
      '__qca': 'P0-443300669-1675200254756',
      'TADANON': 'cEVzaHJDOUlqcHpRZXNKMFZHWEpKTThqamYvc3I3VWptYUZjUXg2em9hSGdZekNhV2xOZVdXL2dkREhIL1ZzTA--',
      'TAPAD': '%7B%22id%22%3A%228013ff31-f61b-4c8f-981e-dfe29af1fd4f%22%7D',
      'uids': '...',
      '__gpi': 'UID=000009ea849cce83:T=1675200257:RT=1675251842:S=ALNI_MaujIx1XiDV-pqu1-3wyBjN3tHc6g',
      'cto_bundle': 'SzuKnF9sYkFNUTg4SkdrT2Q4VXNYNVZyR2dHVjIwOHhsVTZTTWQ5Znk4Vk9GN0JrJTJGM1RtVUYlMkJWUjdRJTJCRWNJbW9rdjFDWnlHTGZuZ281ZjBYc04lMkJUM0xXbW1EU3JIaHNtUXRqVzM4WUlSJTJGa295UTJReU4lMkZ6UmNtallqNDV3cCUyRnY0eExmNFcyOFJrRUMzcjhNTHJzVVRHZHpaUSUzRCUzRA',
      'cto_bidid': 'wduVkV92Z3RleHd4NHQ5bUFMdDJrY3lEcVQ1T0Z5T3diQVglMkJkYlNFdG0xc3JIRGRwZ0ZrM0lqcVVCcVJpQlJxSWFtcXBRaWhpVE85b1NSUlUlMkJoZjglMkZGWE51bXk2USUyQnB2RDJqYVpmJTJCY1BsZzQzRTJjVERzZmNmekc4dVk1TDZxMiUyQjVwZw',
  }

  headers = {
      'authority': 'www.timeanddate.com',
      'accept': '*/*',
      'accept-language': 'es-ES,es;q=0.9,en;q=0.8',
      # 'cookie': '_pbjs_userid_consent_data=3524755945110770; _sharedID=c673f09b-e619-43c6-971b-c0d67e16f49c; __gads=ID=29480aa4712e38d7:T=1675200257:S=ALNI_MZv1zk4XHCqgmGiU-c0XTo4bbdBww; __qca=P0-443300669-1675200254756; TADANON=cEVzaHJDOUlqcHpRZXNKMFZHWEpKTThqamYvc3I3VWptYUZjUXg2em9hSGdZekNhV2xOZVdXL2dkREhIL1ZzTA--; TAPAD=%7B%22id%22%3A%228013ff31-f61b-4c8f-981e-dfe29af1fd4f%22%7D; uids=...; __gpi=UID=000009ea849cce83:T=1675200257:RT=1675251842:S=ALNI_MaujIx1XiDV-pqu1-3wyBjN3tHc6g; cto_bundle=SzuKnF9sYkFNUTg4SkdrT2Q4VXNYNVZyR2dHVjIwOHhsVTZTTWQ5Znk4Vk9GN0JrJTJGM1RtVUYlMkJWUjdRJTJCRWNJbW9rdjFDWnlHTGZuZ281ZjBYc04lMkJUM0xXbW1EU3JIaHNtUXRqVzM4WUlSJTJGa295UTJReU4lMkZ6UmNtallqNDV3cCUyRnY0eExmNFcyOFJrRUMzcjhNTHJzVVRHZHpaUSUzRCUzRA; cto_bidid=wduVkV92Z3RleHd4NHQ5bUFMdDJrY3lEcVQ1T0Z5T3diQVglMkJkYlNFdG0xc3JIRGRwZ0ZrM0lqcVVCcVJpQlJxSWFtcXBRaWhpVE85b1NSUlUlMkJoZjglMkZGWE51bXk2USUyQnB2RDJqYVpmJTJCY1BsZzQzRTJjVERzZmNmekc4dVk1TDZxMiUyQjVwZw',
      'referer': 'https://www.timeanddate.com/weather/australia/sydney/historic?month=7&year=2012',
      'sec-ch-ua': '"Not_A Brand";v="99", "Google Chrome";v="109", "Chromium";v="109"',
      'sec-ch-ua-mobile': '?0',
      'sec-ch-ua-platform': '"Windows"',
      'sec-fetch-dest': 'empty',
      'sec-fetch-mode': 'cors',
      'sec-fetch-site': 'same-origin',
      'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36',
  }


  response = requests.get(
      f'https://www.timeanddate.com/scripts/cityajax.php?n=australia/sydney&mode=historic&hd={date}&month={month}&year={year}&json=1',
      cookies=cookies,
      headers=headers,
  )

  soup = BeautifulSoup(response.content, 'html.parser')
  return demjson.decode(soup.text)

# %%
ls_datos_clima = []
date_from = datetime(year=2012, month=7, day=1)
#date_to = datetime(year=2013, month=6, day=30)
date_to = datetime(year=2012, month=7, day=3)
date_iterador = date_from

while(date_iterador <= date_to):

  day = str(date_iterador.day)
  year = str(date_iterador.year)
  month = str(date_iterador.month)
  date = str(year) + ('00' + month)[-2:] + ('00' + day)[-2:]

  json_data = get_data(date, month, year)

  for index in range(len(json_data)):
    
    json_record = {
        'Date': date_iterador.strftime('%Y-%m-%d'),
        'Hour': json_data[index]['c'][0]['h'][0:5],
        'Temp': normalize('NFKD', json_data[index]['c'][2]['h']),
        'Weather': json_data[index]['c'][3]['h'],
        'Wind': json_data[index]['c'][4]['h'],
        'Humidity': json_data[index]['c'][6]['h'],
        'Barometer': json_data[index]['c'][7]['h'],
        'Visibility': normalize('NFKD', json_data[index]['c'][8]['h'])
    }

    ls_datos_clima.append(json_record)

  date_iterador = (date_iterador + timedelta(days=1))


df_clima = pd.DataFrame.from_records(ls_datos_clima)
df_clima
# Out:
#            Date   Hour   Temp Weather    Wind Humidity  Barometer Visibility
# 0    2012-07-01  12:00  54 °F  Clear.   7 mph      54%  29.95 "Hg      10 mi
# 1    2012-07-01  12:30  54 °F  Clear.   7 mph      54%  29.95 "Hg      10 mi
# 2    2012-07-01  1:00   54 °F  Clear.   6 mph      54%  29.95 "Hg      10 mi
# 3    2012-07-01  2:00   54 °F  Clear.   5 mph      54%  29.95 "Hg      10 mi
# 4    2012-07-01  2:30   50 °F  Clear.   1 mph      67%  29.95 "Hg      10 mi
# ..          ...    ...    ...     ...     ...      ...        ...        ...
# 125  2012-07-03  9:00   50 °F  Clear.  14 mph      58%  30.12 "Hg      10 mi
# 126  2012-07-03  9:30   50 °F  Clear.  17 mph      58%  30.12 "Hg      10 mi
# 127  2012-07-03  10:00  52 °F  Clear.  20 mph      54%  30.12 "Hg      10 mi
# 128  2012-07-03  10:30  52 °F  Clear.  18 mph      54%  30.12 "Hg      10 mi
# 129  2012-07-03  11:00  50 °F  Clear.  18 mph      58%  30.15 "Hg      10 mi
#
# [130 rows x 8 columns]

# %%
df_clima.sort_values(by=['Date','Hour'])
# Out:
#            Date   Hour   Temp            Weather    Wind Humidity  Barometer  \
# 17   2012-07-01  10:00  54 °F      Partly sunny.  12 mph      54%  30.01 "Hg
# 38   2012-07-01  10:00  50 °F             Clear.  13 mph      54%  29.98 "Hg
# 18   2012-07-01  10:30  57 °F  Scattered clouds.  12 mph      48%  29.98 "Hg
# 19   2012-07-01  11:00  59 °F  Scattered clouds.  10 mph      45%  29.98 "Hg
# 39   2012-07-01  11:00  50 °F             Clear.  13 mph      54%  29.98 "Hg
# ..          ...    ...    ...                ...     ...      ...        ...
# 102  2012-07-03  8:30   50 °F             Sunny.  18 mph      58%  30.12 "Hg
# 103  2012-07-03  9:00   52 °F             Sunny.  17 mph      54%  30.12 "Hg
# 125  2012-07-03  9:00   50 °F             Clear.  14 mph      58%  30.12 "Hg
# 104  2012-07-03  9:30   52 °F             Sunny.  20 mph      54%  30.12 "Hg
# 126  2012-07-03  9:30   50 °F             Clear.  17 mph      58%  30.12 "Hg
#
#     Visibility
# 17         N/A
# ...

# %%
import requests

cookies = {
    '_pbjs_userid_consent_data': '3524755945110770',
    '_sharedID': 'c673f09b-e619-43c6-971b-c0d67e16f49c',
    '__gads': 'ID=29480aa4712e38d7:T=1675200257:S=ALNI_MZv1zk4XHCqgmGiU-c0XTo4bbdBww',
    '__qca': 'P0-443300669-1675200254756',
    'TADANON': 'cEVzaHJDOUlqcHpRZXNKMFZHWEpKTThqamYvc3I3VWptYUZjUXg2em9hSGdZekNhV2xOZVdXL2dkREhIL1ZzTA--',
    'TAPAD': '%7B%22id%22%3A%228013ff31-f61b-4c8f-981e-dfe29af1fd4f%22%7D',
    'uids': '...',
    '__gpi': 'UID=000009ea849cce83:T=1675200257:RT=1675251842:S=ALNI_MaujIx1XiDV-pqu1-3wyBjN3tHc6g',
    'cto_bundle': 'SzuKnF9sYkFNUTg4SkdrT2Q4VXNYNVZyR2dHVjIwOHhsVTZTTWQ5Znk4Vk9GN0JrJTJGM1RtVUYlMkJWUjdRJTJCRWNJbW9rdjFDWnlHTGZuZ281ZjBYc04lMkJUM0xXbW1EU3JIaHNtUXRqVzM4WUlSJTJGa295UTJReU4lMkZ6UmNtallqNDV3cCUyRnY0eExmNFcyOFJrRUMzcjhNTHJzVVRHZHpaUSUzRCUzRA',
    'cto_bidid': 'wduVkV92Z3RleHd4NHQ5bUFMdDJrY3lEcVQ1T0Z5T3diQVglMkJkYlNFdG0xc3JIRGRwZ0ZrM0lqcVVCcVJpQlJxSWFtcXBRaWhpVE85b1NSUlUlMkJoZjglMkZGWE51bXk2USUyQnB2RDJqYVpmJTJCY1BsZzQzRTJjVERzZmNmekc4dVk1TDZxMiUyQjVwZw',
}

headers = {
    'authority': 'www.timeanddate.com',
    'accept': '*/*',
    'accept-language': 'es-ES,es;q=0.9,en;q=0.8',
    # 'cookie': '_pbjs_userid_consent_data=3524755945110770; _sharedID=c673f09b-e619-43c6-971b-c0d67e16f49c; __gads=ID=29480aa4712e38d7:T=1675200257:S=ALNI_MZv1zk4XHCqgmGiU-c0XTo4bbdBww; __qca=P0-443300669-1675200254756; TADANON=cEVzaHJDOUlqcHpRZXNKMFZHWEpKTThqamYvc3I3VWptYUZjUXg2em9hSGdZekNhV2xOZVdXL2dkREhIL1ZzTA--; TAPAD=%7B%22id%22%3A%228013ff31-f61b-4c8f-981e-dfe29af1fd4f%22%7D; uids=...; __gpi=UID=000009ea849cce83:T=1675200257:RT=1675251842:S=ALNI_MaujIx1XiDV-pqu1-3wyBjN3tHc6g; cto_bundle=SzuKnF9sYkFNUTg4SkdrT2Q4VXNYNVZyR2dHVjIwOHhsVTZTTWQ5Znk4Vk9GN0JrJTJGM1RtVUYlMkJWUjdRJTJCRWNJbW9rdjFDWnlHTGZuZ281ZjBYc04lMkJUM0xXbW1EU3JIaHNtUXRqVzM4WUlSJTJGa295UTJReU4lMkZ6UmNtallqNDV3cCUyRnY0eExmNFcyOFJrRUMzcjhNTHJzVVRHZHpaUSUzRCUzRA; cto_bidid=wduVkV92Z3RleHd4NHQ5bUFMdDJrY3lEcVQ1T0Z5T3diQVglMkJkYlNFdG0xc3JIRGRwZ0ZrM0lqcVVCcVJpQlJxSWFtcXBRaWhpVE85b1NSUlUlMkJoZjglMkZGWE51bXk2USUyQnB2RDJqYVpmJTJCY1BsZzQzRTJjVERzZmNmekc4dVk1TDZxMiUyQjVwZw',
    'referer': 'https://www.timeanddate.com/weather/australia/sydney/historic?month=7&year=2012',
    'sec-ch-ua': '"Not_A Brand";v="99", "Google Chrome";v="109", "Chromium";v="109"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36',
}

response = requests.get(
    'https://www.timeanddate.com/scripts/cityajax.php?n=australia/sydney&mode=historic&hd=20120702&month=7&year=2012&json=1',
    cookies=cookies,
    headers=headers,
)

# %%
response.content
# Out:
# b'[{c:[{h:"12:00 am<br><span class=\\"smaller soft\\">Mon, Jul 2<\\/span>"},{s:"wt-ic",h:"<img class=mtt title=\\"Clear.\\" src=\\"\\/\\/c.tadst.com\\/gfx\\/w\\/svg\\/wt-13.svg\\" width=40 height=40>"},{h:"48&nbsp;\xc2\xb0F"},{s:"small",h:"Clear."},{s:"sep",h:"9 mph"},{h:"<span class=\\"comp sa12\\" title=\\"Wind blowing from 310\xc2\xb0 Northwest to Southeast\\">\xe2\x86\x91<\\/span>"},{h:"58%"},{s:"sep",h:"29.95 \\"Hg"},{h:"10&nbsp;mi"}]},{c:[{h:"12:30 am"},{s:"wt-ic",h:"<img class=mtt title=\\"Clear.\\" src=\\"\\/\\/c.tadst.com\\/gfx\\/w\\/svg\\/wt-13.svg\\" width=40 height=40>"},{h:"48&nbsp;\xc2\xb0F"},{s:"small",h:"Clear."},{s:"sep",h:"10 mph"},{h:"<span class=\\"comp sa10\\" title=\\"Wind blowing from 300\xc2\xb0 West-northwest to East-southeast\\">\xe2\x86\x91<\\/span>"},{h:"62%"},{s:"sep",h:"29.95 \\"Hg"},{h:"10&nbsp;mi"}]},{c:[{h:"1:00 am"},{s:"wt-ic",h:"<img class=mtt title=\\"Clear.\\" src=\\"\\/\\/c.tadst.com\\/gfx\\/w\\/svg\\/wt-13.svg\\" width=40 height=40>"},{h:"46&nbs
# ...
