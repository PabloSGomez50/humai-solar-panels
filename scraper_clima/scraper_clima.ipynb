# %%
# !pip install demjson

# https://www.timeanddate.com/weather/australia/sydney/historic?month=7&year=2012
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting demjson
#   Downloading demjson-2.2.4.tar.gz (131 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.5/131.5 KB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: demjson
#   Building wheel for demjson (setup.py) ... done
#   Created wheel for demjson: filename=demjson-2.2.4-py3-none-any.whl size=73565 sha256=e4db51b9cec670a33c531db4dea9d2b9513a1cc91ad5d8ea9070975f30f6fc53
#   Stored in directory: /root/.cache/pip/wheels/9c/c3/a5/ad09d152d6b4b24c3f3b6fe2793092ac03e2521e08240d28cf
# Successfully built demjson
# Installing collected packages: demjson
# Successfully installed demjson-2.2.4

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
import demjson
from unicodedata import normalize
from datetime import datetime, timedelta
import re
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import requests
#       2 from bs4 import BeautifulSoup
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'requests'

# %%
def get_data(date, month, year):
  cookies = {
      '_pbjs_userid_consent_data': '3524755945110770',
      '_sharedID': 'c673f09b-e619-43c6-971b-c0d67e16f49c',
      '__gads': 'ID=29480aa4712e38d7:T=1675200257:S=ALNI_MZv1zk4XHCqgmGiU-c0XTo4bbdBww',
      '__qca': 'P0-443300669-1675200254756',
      'TADANON': 'cEVzaHJDOUlqcHpRZXNKMFZHWEpKTThqamYvc3I3VWptYUZjUXg2em9hSGdZekNhV2xOZVdXL2dkREhIL1ZzTA--',
      'TAPAD': '%7B%22id%22%3A%228013ff31-f61b-4c8f-981e-dfe29af1fd4f%22%7D',
      'uids': '...',
      '__gpi': 'UID=000009ea849cce83:T=1675200257:RT=1675251842:S=ALNI_MaujIx1XiDV-pqu1-3wyBjN3tHc6g',
      'cto_bundle': '2PgB1V9sYkFNUTg4SkdrT2Q4VXNYNVZyR2dCTEhQaEE1bzlxOTQ3dVhGRlNsSUxRZnZHSHhqODhzcnpTaEtFb1RVTmY3dDNzZURXSmxKT2UwNWVXRkNNcDJJWWVPVHhTcmJ1ZVM2SCUyQjA0U0dpMjRIVHVVOUFld0JsQ3ZEaDI1Z2t2dWglMkZDYzM3dWRNeGNTQjNPSWdpaGNsSTl3JTNEJTNE',
      'cto_bidid': '-b2VY192Z3RleHd4NHQ5bUFMdDJrY3lEcVQ1T0Z5T3diQVglMkJkYlNFdG0xc3JIRGRwZ0ZrM0lqcVVCcVJpQlJxSWFtcXBRaWhpVE85b1NSUlUlMkJoZjglMkZGWE51dEVWeGVHZDFTTXY4T21QbFNJTmVQajhBbGIzUHQzUnU2eUJ4bSUyRkwzcjY0',
  }

  headers = {
      'authority': 'www.timeanddate.com',
      'accept': '*/*',
      'accept-language': 'es-ES,es;q=0.9,en;q=0.8',
      # 'cookie': '_pbjs_userid_consent_data=3524755945110770; _sharedID=c673f09b-e619-43c6-971b-c0d67e16f49c; __gads=ID=29480aa4712e38d7:T=1675200257:S=ALNI_MZv1zk4XHCqgmGiU-c0XTo4bbdBww; __qca=P0-443300669-1675200254756; TADANON=cEVzaHJDOUlqcHpRZXNKMFZHWEpKTThqamYvc3I3VWptYUZjUXg2em9hSGdZekNhV2xOZVdXL2dkREhIL1ZzTA--; TAPAD=%7B%22id%22%3A%228013ff31-f61b-4c8f-981e-dfe29af1fd4f%22%7D; uids=...; __gpi=UID=000009ea849cce83:T=1675200257:RT=1675251842:S=ALNI_MaujIx1XiDV-pqu1-3wyBjN3tHc6g; cto_bundle=2PgB1V9sYkFNUTg4SkdrT2Q4VXNYNVZyR2dCTEhQaEE1bzlxOTQ3dVhGRlNsSUxRZnZHSHhqODhzcnpTaEtFb1RVTmY3dDNzZURXSmxKT2UwNWVXRkNNcDJJWWVPVHhTcmJ1ZVM2SCUyQjA0U0dpMjRIVHVVOUFld0JsQ3ZEaDI1Z2t2dWglMkZDYzM3dWRNeGNTQjNPSWdpaGNsSTl3JTNEJTNE; cto_bidid=-b2VY192Z3RleHd4NHQ5bUFMdDJrY3lEcVQ1T0Z5T3diQVglMkJkYlNFdG0xc3JIRGRwZ0ZrM0lqcVVCcVJpQlJxSWFtcXBRaWhpVE85b1NSUlUlMkJoZjglMkZGWE51dEVWeGVHZDFTTXY4T21QbFNJTmVQajhBbGIzUHQzUnU2eUJ4bSUyRkwzcjY0',
      'referer': f'https://www.timeanddate.com/weather/australia/sydney/historic?month={month}&year={year}',
      'sec-ch-ua': '"Not_A Brand";v="99", "Google Chrome";v="109", "Chromium";v="109"',
      'sec-ch-ua-mobile': '?0',
      'sec-ch-ua-platform': '"Windows"',
      'sec-fetch-dest': 'empty',
      'sec-fetch-mode': 'cors',
      'sec-fetch-site': 'same-origin',
      'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36',
  }


  response = requests.get(
      f'https://www.timeanddate.com/scripts/cityajax.php?n=australia/sydney&mode=historic&hd={date}&month={month}&year={year}&json=1',
      cookies=cookies,
      headers=headers,
  )

  soup = BeautifulSoup(response.content, 'html.parser')
  return demjson.decode(soup.text)

# %%
ls_datos_clima = []
date_from = datetime(year=2012, month=7, day=1)
date_to = datetime(year=2013, month=6, day=30)
date_iterador = date_from
regular_expresion_hora = '^(\d){1,2}:(\d){2} (am|pm)'

while(date_iterador <= date_to):

  day = str(date_iterador.day)
  year = str(date_iterador.year)
  month = str(date_iterador.month)
  date = str(year) + ('00' + month)[-2:] + ('00' + day)[-2:]

  json_data = get_data(date, month, year)

  for index in range(len(json_data)):
    date = date_iterador.strftime('%Y-%m-%d')
    hour_am_pm = re.search(regular_expresion_hora, json_data[index]['c'][0]['h']).group()
    hour_24 = datetime.strftime(datetime.strptime(hour_am_pm, "%I:%M %p"), "%H:%M")
    temp = normalize('NFKD', json_data[index]['c'][2]['h'])
    weather = json_data[index]['c'][3]['h']
    wind = json_data[index]['c'][4]['h']
    humidity = json_data[index]['c'][6]['h'],
    barometer = json_data[index]['c'][7]['h'],
    visibility = normalize('NFKD', json_data[index]['c'][8]['h'])

    json_record = {
        'Date': date,
        'Hour': hour_24,
        'Temp': temp,
        'Weather': weather,
        'Wind': wind,
        'Humidity': humidity,
        'Barometer': barometer,
        'Visibility': visibility
    }

    ls_datos_clima.append(json_record)

  date_iterador = (date_iterador + timedelta(days=1))


df_clima = pd.DataFrame.from_records(ls_datos_clima)
df_clima.sort_values(by=['Date','Hour'])
# Out:
#              Date   Hour   Temp          Weather    Wind Humidity  \
# 0      2012-07-01  00:00  54 °F           Clear.   7 mph   (54%,)
# 1      2012-07-01  00:30  54 °F           Clear.   7 mph   (54%,)
# 2      2012-07-01  01:00  54 °F           Clear.   6 mph   (54%,)
# 3      2012-07-01  02:00  54 °F           Clear.   5 mph   (54%,)
# 4      2012-07-01  02:30  50 °F           Clear.   1 mph   (67%,)
# ...           ...    ...    ...              ...     ...      ...
# 16437  2013-06-30  21:30  54 °F  Passing clouds.   9 mph   (94%,)
# 16438  2013-06-30  22:00  54 °F  Passing clouds.  10 mph   (88%,)
# 16439  2013-06-30  22:30  55 °F  Passing clouds.   7 mph   (82%,)
# 16440  2013-06-30  23:00  54 °F  Passing clouds.   6 mph   (88%,)
# 16441  2013-06-30  23:30  52 °F  Passing clouds.   5 mph   (94%,)
#
#           Barometer Visibility
# 0      (29.95 "Hg,)      10 mi
# 1      (29.95 "Hg,)      10 mi
# 2      (29.95 "Hg,)      10 mi
# 3      (29.95 "Hg,)      10 mi
# 4      (29.95 "Hg,)      10 mi
# ...             ...        ...
# 16437  (30.24 "Hg,)        N/A
# 16438  (30.24 "Hg,)        N/A
# 16439  (30.24 "Hg,)        N/A
# 16440  (30.24 "Hg,)        N/A
# 16441  (30.24 "Hg,)        N/A
#
# [16442 rows x 8 columns]

# %%
df_clima.to_csv('clima_sidney.csv')
